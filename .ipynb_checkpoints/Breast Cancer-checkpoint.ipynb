# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./data.csv')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
#  # Data preprocessing

# %%
df = df.drop(columns='Unnamed: 32')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.shape
# Out:
# (569, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
# Checking if there are any null values in the data set
df.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
sns.set()

# %%
sns.countplot('diagnosis', data=df)
# Out:
# C:\Users\Rahul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='diagnosis', ylabel='count'>

# %%
sns.distplot(df['fractal_dimension_worst'])
# Out:
# C:\Users\Rahul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='fractal_dimension_worst', ylabel='Density'>

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %% [markdown]
# # Plotting a heat map to understand correlation

# %%
correlation = df.corr()

# %%
plt.figure(figsize=(20,20))
sns.heatmap(correlation, cbar=True, square=True, fmt='.1f', annot=True, annot_kws={'size': 10}, cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Plotting a pair plot

# %%
sns.pairplot(df, hue='diagnosis')

# %%
df['diagnosis'].value_counts()

# %%
df.head()

# %%
df.replace({'diagnosis' : {'M' : 1, 'B' : 0}}, inplace=True)

# %%
df.head()

# %%
df.groupby(df['diagnosis']).mean()

# %%
# Creating features and target
X = df.drop(columns=['id', 'diagnosis'])
Y = df['diagnosis']

# %%
print(Y)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# Splitting the data
X_train,X_test,Y_train,Y_test = train_test_split(X, Y, test_size=0.30, stratify=Y, random_state=10)

# %%
print(X.shape,X_train.shape,X_test.shape)

# %% [markdown]
# # Training the model

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)

# %%
# Model Evaluation
X_train_predict = model.predict(X_train)
print(X_train_predict)

# %%
# Checking the accuracy of training prediction
X_train_accuracy = accuracy_score(Y_train, X_train_predict)
print("The Accuracy score on training data is : ",X_train_accuracy)

# %%
X_test_predict = model.predict(X_test)
print(X_test_predict)

# %%
X_test_accuracy = accuracy_score(Y_test, X_test_predict)
print("The accuracy score of test data is : ",X_test_accuracy)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(Y_test, X_test_predict)

# %%
pd.DataFrame(confusion_matrix(Y_test, X_test_predict), columns=['Benign Tumour', 'Malignant Tumour'], index=['Actaully Benign', 'Actually Malignant'])

# %%
def prediction(x):
    input_arr_reshaped = x.reshape(1, -1)
#     print(input_arr_reshaped)
    predict = model.predict(input_arr_reshaped)
    return predict

# %%
# input_data = input().split(",")
# input_arr = np.asarray(input_data)
# # print(input_arr.shape)
# result = prediction(input_arr)
# if(result == True):
#     print("Your Diagnosis has been processed, you have Breast Cancer : Malignant Tumour")
# else:
#     print("Your Diagnosis has been processed, you are safe : Benign Tumour")
